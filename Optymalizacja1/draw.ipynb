# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('test_sym_table.csv')

# %%
df
# Out:
#       Unnamed: 0            Va        Vb
# 0              0  5.000000e+00  1.000000
# 1              1  4.985262e+00  1.014702
# 2              2  4.970545e+00  1.029309
# 3              3  4.955850e+00  1.043823
# 4              4  4.941177e+00  1.058244
# ...          ...           ...       ...
# 996          996 -5.259136e-08  1.265477
# 997          997 -5.259136e-08  1.264231
# 998          998 -5.259136e-08  1.262990
# 999          999 -5.259136e-08  1.261754
# 1000        1000 -5.259136e-08  1.260524
#
# [1001 rows x 3 columns]

# %%
plt.figure(figsize=(10, 6))

plt.plot(df['Unnamed: 0'], df['Va'], label='Va', marker='o')

plt.plot(df['Unnamed: 0'], df['Vb'], label='Vb', marker='x')

plt.xlabel('N')
plt.ylabel('Objentość')
plt.title('Wykres Va i Vb')
plt.legend()

plt.show()
